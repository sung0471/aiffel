# %% [markdown]
# ## Python을 이용한 데이터베이스
# - https://www.python.org/dev/peps/pep-0249/

# %% [markdown]
# ![image.png](attachment:image.png)
# - 파이썬 내장 DB-API로 모든 SQL 기반 데이터베이스를 사용가능
# - SQLite : 설치없이 사용
# - MySQL, Mongo DB 등 : 공식 드라이버 설치 후 사용

# %% [markdown]
# ### 메인함수
# - connect(): 데이터베이스의 연결을 만든다.
# - cursor(): 질의를 관리하기 위한 커서 객체를 만든다. (file의 open과 비슷)
# - execute(), excutemany(): 데이터베이스에 하나 이상의 SQL명령을 실행한다.
# - fetchone(), fetchmany(), fetchall(): 실행 결과를 얻는다.

# %% [markdown]
# ### SQLite
# - https://docs.python.org/3.7/library/sqlite3.html

# %% [markdown]
# #### SQL 연결

# %%
import sqlite3
conn = sqlite3.connect('example.db')

# %% [markdown]
# #### SQL 쿼리를 관리하기 위한 커서 객체 생성

# %%
c = conn.cursor()

# %% [markdown]
# #### 쿼리로 명령어 입력

# %%
# Create table
c.execute('''CREATE TABLE stocks
             (date text, trans text, symbol text, qty real, price real)''')

# Insert a row of data
c.execute("INSERT INTO stocks VALUES ('2006-01-05','BUY','RHAT',100,35.14)")

# %% [markdown]
# #### DB에 반영

# %%
conn.commit()

# %% [markdown]
# #### 끝난 후 종료

# %%
conn.close()

# %% [markdown]
# ### DB 실습

# %% [markdown]
# #### sales 테이블 제작

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
query = """CREATE TABLE sales
(product VARCHAR(20),
maker VARCHAR(40),
amount FLOAT,
data DATE);"""
conn.execute(query)
conn.commit()

# %% [markdown]
# #### sales 테이블에 데이터 삽입

# %%
data = [('smart phone', 'Apple', '47.2', '2019-08-03'),
        ('printer', 'Samsung', '15.2', '2018-02-10',),
        ('monitor', 'LG', '14.25', '2019-12-20'),
        ('python book', 'Amazon', '12.40', '2020-01-23')]
statement = 'INSERT INTO sales VALUES(?,?,?,?)'
conn.executemany(statement, data)
